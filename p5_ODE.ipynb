# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # ODE

# %% [markdown]
# ## Ejercicio 1
# $y'= -5y+5t^2+2t$
# * $0 \le t \le 1$
# * $y(t_0)=1/3$
# * $N=10$

# %%
# %autoreload 2
from src import ODE_euler

# %% [markdown]
# ## Comparación con la solución real
# La solución real de la ecuación diferencial es:
# $y(t)=t^2 +1/3e^{-5t}$
#
# * Grafique la solución real y la aproximación obtenida con el método de Euler en una misma gráfica.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t, y):
    return (-5 * y) + (5 * t**2) + (2 * t)

a=0
b=1
y_t0=1/3
N=10
y_values, t_values, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

def exact_solution(t):
    return t**2 + (1/3 * np.exp(-5 * t))

t_exact = np.linspace(a, b, 100)
y_exact = exact_solution(t_exact)

y_exact_interp = np.interp(t_values, t_exact, y_exact)

error = np.abs((y_values - y_exact_interp) / y_exact_interp)

promedio_error = np.mean(error)

print(f"Promedio del error: {promedio_error:.4e}")

print(f"h value: {h}")
print("t_values\t y_values\t Error" )
print("------------------------")
for t, y, y_e in zip(t_values, y_values, y_exact_interp):
    print(f"{t:.4f}\t {y:.4f} \t {np.abs(y - y_e):.4e}")
# Out:
# Promedio del error: 1.2918e-01
# h value: 0.1
# t_values	 y_values	 Error
# ------------------------
# 0.0000	 0.3333 	 0.0000e+00
# 0.1000	 0.1667 	 4.5543e-02
# 0.2000	 0.1083 	 5.4335e-02
# 0.3000	 0.1142 	 5.0252e-02
# 0.4000	 0.1621 	 4.3067e-02
# 0.5000	 0.2410 	 3.6354e-02
# 0.6000	 0.3455 	 3.1104e-02
# 0.7000	 0.4728 	 2.7329e-02
# 0.8000	 0.6214 	 2.4743e-02
# 0.9000	 0.7907 	 2.3022e-02
# 1.0000	 0.9803 	 2.1901e-02

# %%
plt.plot(t_values, y_values, label='Euler con N=10', marker='o')
plt.plot(t_exact, y_exact, label=' Solucion Exacta', linestyle='--')
plt.xlabel('t')
plt.ylabel('y')
plt.title('ODE')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Errores
# Calcule el eeror relativo para diferentes valores de N.

# %%
N = 5

y_values5, t_values5, h5 = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

y_exact_interp = np.interp(t_values5, t_exact, y_exact)

error = np.abs((y_values5 - y_exact_interp) / y_exact_interp)

promedio_error = np.mean(error)

print(f"Promedio del error: {promedio_error:.4e}")

print(f"h5 value: {h5}")
print("t_values5\t y_values5\t Error" )
print("------------------------")
for t, y, y_e in zip(t_values5, y_values5, y_exact_interp):
    print(f"{t:.4f}\t {y:.4f} \t {np.abs(y - y_e):.6e}")
# Out:
# Promedio del error: 2.7982e-01
# h5 value: 0.2
# t_values5	 y_values5	 Error
# ------------------------
# 0.0000	 0.3333 	 0.000000e+00
# 0.2000	 0.0000 	 1.626681e-01
# 0.4000	 0.1200 	 8.515010e-02
# 0.6000	 0.3200 	 5.662524e-02
# 0.8000	 0.6000 	 4.612277e-02
# 1.0000	 0.9600 	 4.224598e-02

# %%
plt.plot(t_values5, y_values5, label='Euler con N=5', marker='o')
plt.plot(t_exact, y_exact, label=' Solucion Exacta', linestyle='--')
plt.xlabel('t')
plt.ylabel('y')
plt.title('ODE')
plt.legend()
plt.grid()
plt.show()

# %%
N = 20

y_values20, t_values20, h20 = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

y_exact_interp = np.interp(t_values20, t_exact, y_exact)

error = np.abs((y_values20 - y_exact_interp) / y_exact_interp)

promedio_error = np.mean(error)

print(f"Promedio del error: {promedio_error:.4e}")

print(f"h20 value: {h20}")
print("t_values20\t y_values20\t Error" )
print("------------------------")
for t, y, y_e in zip(t_values20, y_values20, y_exact_interp):
    print(f"{t:.4f}\t {y:.4f} \t {np.abs(y - y_e):.4e}")
# Out:
# Promedio del error: 6.3244e-02
# h20 value: 0.05
# t_values20	 y_values20	 Error
# ------------------------
# 0.0000	 0.3333 	 0.0000e+00
# 0.0500	 0.2500 	 1.2121e-02
# 0.1000	 0.1931 	 1.9085e-02
# 0.1500	 0.1573 	 2.2651e-02
# 0.2000	 0.1386 	 2.4035e-02
# 0.2500	 0.1340 	 2.4069e-02
# 0.3000	 0.1411 	 2.3312e-02
# 0.3500	 0.1583 	 2.2135e-02
# 0.4000	 0.1844 	 2.0778e-02
# 0.4500	 0.2183 	 1.9390e-02
# 0.5000	 0.2593 	 1.8062e-02
# 0.5500	 0.3070 	 1.6841e-02
# 0.6000	 0.3609 	 1.5750e-02
# 0.6500	 0.4207 	 1.4795e-02
# 0.7000	 0.4861 	 1.3972e-02
# 0.7500	 0.5571 	 1.3272e-02
# 0.8000	 0.6334 	 1.2682e-02
# 0.8500	 0.7151 	 1.2188e-02
# 0.9000	 0.8019 	 1.1777e-02
# 0.9500	 0.8940 	 1.1437e-02
# 1.0000	 0.9911 	 1.1157e-02

# %%
plt.plot(t_values20, y_values20, label='Euler con N=5', marker='o')
plt.plot(t_exact, y_exact, label=' Solucion Exacta', linestyle='--')
plt.xlabel('t')
plt.ylabel('y')
plt.title('ODE')
plt.legend()
plt.grid()
plt.show()
