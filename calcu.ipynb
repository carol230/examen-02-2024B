# %%
vreal = -0.016107237
vaprox = -0.02000

ea = abs(vreal - vaprox)
er = ea / abs(vreal)

print(f"Error absoluto: {ea:.4e}")

print(f"Error relativo:  {er:.4e}")
print(er)
# Out:
# Error absoluto: 3.8928e-03
# Error relativo:  2.4168e-01
# 0.2416778867784711

# %%
vreal = -62.083893
vaprox = -62.08

ea = abs(vreal - vaprox)
er = abs(vreal - vaprox) / abs(vreal)

print(f"Error absoluto: {ea:.4e}")

print(f"Error relativo:  {er:.4e}")
print(er)
# Out:
# Error absoluto: 3.8930e-03
# Error relativo:  6.2705e-05
# 6.270547499340983e-05

# %%
# METODO B

# %%
vreal = -0.016107237
vaprox = -0.016108

ea = abs(vreal - vaprox)
er = ea / abs(vreal)

print(f"Error absoluto: {ea:.5e}")

print(f"Error relativo:  {er:.5e}")
print(er)
# Out:
# Error absoluto: 7.63000e-07
# Error relativo:  4.73700e-05
# 4.737001138065122e-05

# %%
vreal = -62.083893
vaprox = -50

ea = abs(vreal - vaprox)
er = abs(vreal - vaprox) / abs(vreal)

print(f"Error absoluto: {ea:.4e}")

print(f"Error relativo:  {er:.3e}")
print(er)
# Out:
# Error absoluto: 1.2084e+01
# Error relativo:  1.946e-01
# 0.19463813263127688

# %% [markdown]
# ## EJERCICIO 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
vreal = -92.24458
vaprox = -50

ea = abs(vreal - vaprox)
er = abs(vreal - vaprox) / abs(vreal)

print(f"Error absoluto: {ea:.4e}")

print(f"Error relativo:  {er:.3e}")
print(er)
# Out:
# Error absoluto: 1.2084e+01
# Error relativo:  1.946e-01
# 0.19463813263127688

# %%
vreal = 0.0054203727
vaprox = -50

ea = abs(vreal - vaprox)
er = abs(vreal - vaprox) / abs(vreal)

print(f"Error absoluto: {ea:.4e}")

print(f"Error relativo:  {er:.3e}")
print(er)
